# %% [markdown]
# # Make a Library

# %% [markdown]
# ## 1. Import From Intlib
#
# Footprints are .intlibs -
# 1. ^O 🢜🢜🢜🢜🢜🡲 .IntLib 🢜🢜🢜🢜🢜🡲 Extract

# %% [markdown]
# ## 2. Mouser Imports
#
# Mouser or other sites will need the [Altium Library loader](https://www.samacsys.com/altiumll-install/)
#
# ![image.png](attachment:image.png)
#
#
# There needs to be a schematic doc created before "Add to Design" is pressed.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3. UL - Ultra Librarian Extraction
#
# File 🢜🢜🢜🢜🢜🡲 Run Script 🢜🢜🢜🢜🢜🡲 .PrjScr
#
# <center><img src="./img/Screenshot 2024-11-09 131940.png" width="200"/></center>
#
# Click the main one:
#
# <center><img src="./img/Screenshot 2024-11-09 132338.png" width="600"/></center>
#
# Point to the txt file:
#
# <center><img src="./img/Screenshot 2024-11-09 132658.png" width="600"/></center>

# %% [markdown]
# ## Copy After Extraction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center><img src="./img/Screenshot 2024-11-09 125957.png" height="400"/></center>

# %% [markdown]
# Click copy
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Paste in the project's PCB library
#
# ![image.png](attachment:image.png)
#
#
# Delete PCB Comp 1 since we dont need it anymore
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # DIY Footprints
#
# ## 1. Automatically
#
# <center><img src="./img/Screenshot 2024-11-09 142325.png" width="400"/></center>
#
# ## 2. By Hand
#
# Add and rename accordingly, Use toolkit bar to design.
#
# <center><img src="./img/Screenshot 2024-11-09 133830.png" width="600"/></center>
#
# Pads or pads with holes can be added
#
# <center><img src="./img/Screenshot 2024-11-09 135126.png" width="300"/>&emsp; <img src="./img/Screenshot 2024-11-09 135215.png" width="300"/><center>
#
# The property tab allows one to modify pad types thru here:
#
# <center><img src="./img/Screenshot 2024-11-09 134217.png" width="200"/></center>
#
# The hole sizes can be changed here as well.
#
# <center><img src="./img/Screenshot 2024-11-09 134740.png" width="100"/></center>

# %% [markdown]
# # DIY Schematic
#
# ## 1. Take an existing model
#
# <center><img src="./img/Screenshot 2024-11-09 141306.png" width="300"/>&emsp; <img src="./img/Screenshot 2024-11-09 141400.png" width="300"/></center>
#
# ## 2. Using Symbol Wizard
#
# >Note you need to be in the .SchLib file to see this option!
#
# <center><img src="./img/Screenshot 2024-11-09 142843.png" width="200"/></center>
# <center><img src="./img/Screenshot 2024-11-09 142830.png" width="300"/></center>
# <center><img src="./img/Screenshot 2024-11-09 143235.png" width="600"/></center>

# %% [markdown]
# # Linking Schematic to Footprint
#
# >Use Footprint not Model!
#
# <center><img src="./img/Screenshot 2024-11-09 144525.png" width="600"/></center>

# %% [markdown]
# # PCB Layout
#
# <center><img src="./img/Screenshot 2024-11-09 145025.png" width="600"/></center>
#
# >Note one might need to refresh libs if things no worko
#
# <center><img src="./img/Screenshot 2024-11-09 145711.png" width="600"/></center>
#
# If errors occur check to see if the footprint assignment failed or not.

# %% [markdown]
# # Nav
#
# Spacebar - Rotate
#
# Layers Below
# <center><img src="./img/Screenshot 2024-11-09 151541.png" width="600"/></center>
#
#
# ## 3D
#
# Rotate:
# * +RMB
# * Numpad arrows + Sets (7, 9, 1, 3)
#
# Pan:
# * RMB
# * ^Numpad arrows
#
# Zoom
# * MMB

# %% [markdown]
# # Markings
#
# <center><img src="./img/Screenshot 2024-11-09 153305.png" width="250"/></center>

# %% [markdown]
# # Design Choices
#
# [Trace Width](https://www.advancedpcb.com/en-us/tools/trace-width-calculator/) Calculator
